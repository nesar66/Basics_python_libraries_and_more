# %%
#https://www.youtube.com/watch?v=vmEHCJofslg
# next day work on loc and groupby
import numpy as np
import pandas as pd

# %%
# edited

# %%
#load data
pokemon_data=pd.read_csv("pokemon_data.csv") # pd.read_excel,
#pokemon_data=pd.read_csv("pokemon_data.txt", delimiter="\t")
#pokemon_data.head()
#pokemon_data.tail()

# %%
print(pokemon_data.columns)
#print(pokemon_data['Name'])
print(type(pokemon_data["Name"]))
pokemon_data[["Name"]]
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# <class 'pandas.core.series.Series'>
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %%
# using iloc function is used to get rows
pokemon_data.iloc[0:,0:5]
# Out:
#        #                   Name   Type 1  Type 2  HP
# 0      1              Bulbasaur    Grass  Poison  45
# 1      2                Ivysaur    Grass  Poison  60
# 2      3               Venusaur    Grass  Poison  80
# 3      3  VenusaurMega Venusaur    Grass  Poison  80
# 4      4             Charmander     Fire     NaN  39
# ..   ...                    ...      ...     ...  ..
# 795  719                Diancie     Rock   Fairy  50
# 796  719    DiancieMega Diancie     Rock   Fairy  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80
# 799  721              Volcanion     Fire   Water  80
#
# [800 rows x 5 columns]

# %%
#loc prints specific values in columns
pokemon_data_1=pokemon_data.loc[(pokemon_data['Type 1']=='Grass') & (pokemon_data['HP']>60) ]
pokemon_data_1
# Out:
#        #                     Name Type 1    Type 2   HP  Attack  Defense  \
# 2      3                 Venusaur  Grass    Poison   80      82       83
# 3      3    VenusaurMega Venusaur  Grass    Poison   80     100      123
# 50    45                Vileplume  Grass    Poison   75      80       85
# 76    70               Weepinbell  Grass    Poison   65      90       50
# 77    71               Victreebel  Grass    Poison   80     105       65
# 111  103                Exeggutor  Grass   Psychic   95      95       85
# 122  114                  Tangela  Grass       NaN   65      55      115
# 168  154                 Meganium  Grass       NaN   80      82      100
# 197  182                Bellossom  Grass       NaN   75      80       95
# 204  189                 Jumpluff  Grass    Flying   75      55       70
# 207  192                 Sunflora  Grass       NaN   75      75       55
# 274  254                 Sceptile  Grass       NaN   70      85       65
# ...

# %%
#learn more about this later
#for index, row in pokemon_data.iterrows():
# print(index,row["Name"])
#for index, row in pokemon_data.iterrows():
# print(row["Type 1"])
for index, row in pokemon_data.iterrows():
  print(index)

# %%
#pokemon_data.sort_values("Name", ascending=True)
pokemon_data_2=pokemon_data.sort_values(['Name','HP'], ascending=[0,0])
pokemon_data_2
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
#making some changes in dataframe
#HP	Attack	Defense	Sp. Atk	Sp. Def	Speed
pokemon_data_2['Totals']=pokemon_data['HP']+ pokemon_data['Attack']+ pokemon_data['Defense']+ pokemon_data['Sp. Atk']+ pokemon_data['Sp. Def']+ pokemon_data['Speed']
pokemon_data_2
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Totals
# ...

# %%
pokemon_data_2=pokemon_data_2.drop(["Totals"], axis=1)

# %%
# modifying columns using iloc
pokemon_data_2=pd.read_csv("pokemon_data.csv")
pokemon_data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon_data_2['Total']=pokemon_data.iloc[:,4:10].sum(axis=1)

# %%
pokemon_data_2.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
columns=list(pokemon_data_2.columns)

# %%
type(columns)
# Out:
# list

# %%
pokemon_data_2.head()
pokemon_data_2=pokemon_data_2.drop(columns="#")

# %%
pokemon_data_2.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total'],
#       dtype='object')

# %%
#re arranging the columns
cols=list(pokemon_data_2.columns)
# print(type(cols))
#pokemon_data=pokemon_data[cols[0:4] + cols[-1]+ cols [4:12]] # it will show an error, because cols[-1] is a single element, to make it a list
#pokemon_data=pokemon_data[cols[0:4] + [cols[-1]]+ cols [4:12]] # it will show an error, because cols[-1] is a single element, to make it a list
# pokemon_data
pokemon_data_2=pokemon_data_2[cols[0:4]+[cols[-1]]+cols[4:12]]
pokemon_data_2
# Out:
#                       Name   Type 1  Type 2  HP  Total  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison  45    318      49       49
# 1                  Ivysaur    Grass  Poison  60    405      62       63
# 2                 Venusaur    Grass  Poison  80    525      82       83
# 3    VenusaurMega Venusaur    Grass  Poison  80    625     100      123
# 4               Charmander     Fire     NaN  39    309      52       43
# ..                     ...      ...     ...  ..    ...     ...      ...
# 795                Diancie     Rock   Fairy  50    600     100      150
# 796    DiancieMega Diancie     Rock   Fairy  50    700     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost  80    600     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark  80    680     160       60
# 799              Volcanion     Fire   Water  80    600     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
#saving dataframe as a csv
from google.colab import files
pokemon_data_new=pokemon_data.to_csv('pokemon_data_new.csv')
#df.to_excel

# %%
pokemon_data_2.loc[(pokemon_data["Legendary"]==True) | (pokemon_data["Type 1"]=="Electric")]
# Out:
#        #                 Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 30    25              Pikachu  Electric    NaN  35      55       40       50
# 31    26               Raichu  Electric    NaN  60      90       55       90
# 88    81            Magnemite  Electric  Steel  25      35       70       95
# 89    82             Magneton  Electric  Steel  50      60       95      120
# 108  100              Voltorb  Electric    NaN  40      30       50       55
# ..   ...                  ...       ...    ...  ..     ...      ...      ...
# 795  719              Diancie      Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie      Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined   Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound   Psychic   Dark  80     160       60      170
# 799  721            Volcanion      Fire  Water  80     110      120      130
#
# ...

# %%
pokemon_data_6= pokemon_data_4.loc[(pokemon_data_4["Type 1"]=="Grass") | (pokemon_data_4["Type 2"]=="Poison")]

# %%
# pokemon_data.loc[pokemon_data["Type 1"]=="Grass"]
pokemon_data_new2=pokemon_data.loc[(pokemon_data["Type 1"]=="Grass") | (pokemon_data["Type 2"]=="Poison")]
#pokemon_data_new2=pokemon_data_new2.reset_index()
pokemon_data_new=pokemon_data.loc[(pokemon_data)]

# %%
# column contains only mega
pokemon_data.drop(columns="#")
#pokemon_data.loc[pokemon_data["Name"].str.contains("Mega")]
#pokemon_data.loc[pokemon_data["Type 1"].str.contains("Gra")]

# %%
pokemon_data1=pokemon_data.loc[pokemon_data["Name"].str.contains("Gra")]
pokemon_data_7=pokemon_data_6.loc[pokemon_data_6["Name"].str.contains("Ve")]

# %%
# contains either fire or grass in Type 1
import re
#pokemon_data.loc[pokemon_data["Type 1"].str.contains("Mega|Grass", regex=True)]
pokemon_data_4=pokemon_data.loc[pokemon_data['Type 1'].str.contains("Ground|Grass", regex=True)]

# %%
pokemon_data_4
# Out:
#        #                   Name  Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur   Grass    Poison   45      49       49
# 1      2                Ivysaur   Grass    Poison   60      62       63
# 2      3               Venusaur   Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur   Grass    Poison   80     100      123
# 32    27              Sandshrew  Ground       NaN   50      75       85
# ..   ...                    ...     ...       ...  ...     ...      ...
# 718  650                Chespin   Grass       NaN   56      61       65
# 719  651              Quilladin   Grass       NaN   61      78       95
# 720  652             Chesnaught   Grass  Fighting   88     107      122
# 740  672                 Skiddo   Grass       NaN   66      65       48
# 741  673                 Gogoat   Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# aggregate statistics by grou by. Three kinds of work for group by mean, sum and count

pokemon_data=pd.read_csv("pokemon_data.csv")
#pokemon_data.groupby("Type 1").mean().sort_values("HP")

# %%
pokemon_data.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pokemon_data.groupby("Legendary").nunique()
# Out:
#              #  Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Legendary
# False      675   735      18      18  92     107      100      100       88
# True        46    65      15      13  18      23       23       25       24
#
#            Speed  Generation
# Legendary
# False        105           6
# True          23           6

# %%
pokemon_data_8.describe()

# %%
pokemon_data.groupby("Type 1").count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %%
# working with large number of datasets
for pokemon_data in pd.read_csv("pokemon_data.csv", chunksize=45):
  print(pokemon_data)
# Out:
#      #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 0    1                  Bulbasaur     Grass  Poison   45      49       49
# 1    2                    Ivysaur     Grass  Poison   60      62       63
# 2    3                   Venusaur     Grass  Poison   80      82       83
# 3    3      VenusaurMega Venusaur     Grass  Poison   80     100      123
# 4    4                 Charmander      Fire     NaN   39      52       43
# 5    5                 Charmeleon      Fire     NaN   58      64       58
# 6    6                  Charizard      Fire  Flying   78      84       78
# 7    6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 8    6  CharizardMega Charizard Y      Fire  Flying   78     104       78
# 9    7                   Squirtle     Water     NaN   44      48       65
# 10   8                  Wartortle     Water     NaN   59      63       80
# 11   9                  Blastoise     Water     NaN   79      83      100
# ...

# %%
a=[pokemon_data for pokemon_data in pd.read_csv("pokemon_data.csv", chunksize=20)]
print(a)
# Out:
# [     #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison  45      49       49
# 1    2                    Ivysaur  Grass  Poison  60      62       63
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 9    7                   Squirtle  Water     NaN  44      48       65
# 10   8                  Wartortle  Water     NaN  59      63       80
# 11   9                  Blastoise  Water     NaN  79      83      100
# ...
